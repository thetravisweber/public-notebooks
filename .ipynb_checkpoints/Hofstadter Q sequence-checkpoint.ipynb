# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
class Entry:
    
    def __init__(self, index, num):
        self.index = index
        self.num = num
        self.references = []
        
    def notify_referenced_by(self, m):
        self.references.append(m)
        
    def greatest_ref(self):
        if self.num_ref() > 0: 
            return max(self.references)
        return 0
    
    def least_ref(self):
        if self.num_ref() > 0: 
            return min(self.references)
        return 0
    
    def num_ref(self):
        return len(self.references)
        
    def __str__(self):
        return str(self.index) + ": " + str(self.num)
    
    def __add__(self, other):
        return self.num + other.num

# %%
def add_a_term(predict_die, notify=True):
    current = len(seq) + 1
    # python equivalent of current index
    p_current = current - 1
    
    # calculate indeces [including conversions to and from 0-indexed]
    firstIndex = p_current - seq[p_current-1].num
    secondIndex = p_current - seq[p_current-2].num
    
    # Check entries are valid
    if ((firstIndex < 0) or (secondIndex < 0)):
        print("accessing indeces ", firstIndex + 1,", ", secondIndex + 1)
        return False
    
    # notify other entries
    if (notify):
        try:
            seq[firstIndex].notify_referenced_by(current)
            seq[secondIndex].notify_referenced_by(current)
        except:
            print(firstIndex, secondIndex, len(seq))
            return False
    
    seq.append(Entry(current, seq[firstIndex] + seq[secondIndex]))
    return True

# %%
def add_terms(n, predict_die=False, notify=True):
    for _ in range(n):
        if (not add_a_term(predict_die)):
            print("DIED")
            return False
        if (predict_die):
            pretty_print()

# %%
def pretty_print(include_index = False):
    for ent in seq:
        if (include_index):
            print(ent, end = '')
            print(str(ent.num) + "-> ", end='')
    print()

# %%
def pretty_str(sequence):
    res = ""
    for ent in sequence:
        res+=str(ent.num) + "-> "
    return res

# %%
def default():
    return [Entry(1, 1), Entry(2, 1)]

# %%
seq = default()
first_worked = add_terms(40)
pretty_print()
if (first_worked and not add_terms(500)):
    pretty_print()
# Out:
# 1-> 1-> 2-> 3-> 3-> 4-> 5-> 5-> 6-> 6-> 6-> 8-> 8-> 8-> 10-> 9-> 10-> 11-> 11-> 12-> 12-> 12-> 12-> 16-> 14-> 14-> 16-> 16-> 16-> 16-> 20-> 17-> 17-> 20-> 21-> 19-> 20-> 22-> 21-> 22-> 23-> 23->

# %%
def display_wide_table(ourSeq):
    print("  n | Q(n) | Q(n - (n-1)) | Q(n - (n-2)) | n - Q(n-1) | n - Q(n-2)")
    global seq
    for ent in ourSeq:
        if (ent.index > 2):
            prev = seq[ent.index - 2]
            doublePrev = seq[ent.index - 3]
            firstTermIndex = ent.index - prev.num
            secondTermIndex = ent.index - doublePrev.num
            firstContributingNum = seq[firstTermIndex - 1].num
            secondContributingNum = seq[secondTermIndex - 1].num
            print("%3d | %4d |  %7d     |  %7d     | %7d    | %5d" % (ent.index, ent.num, firstContributingNum, \
                                                     secondContributingNum, firstTermIndex, secondTermIndex))
        else:
            print("%3d | %4d |              |              |            |" % (ent.index, ent.num))

# %%
display_wide_table(seq[:12])
# Out:
#   n | Q(n) | Q(n - (n-1)) | Q(n - (n-2)) | n - Q(n-1) | n - Q(n-2)
#   1 |    1 |              |              |            |
#   2 |    1 |              |              |            |
#   3 |    2 |        1     |        1     |       2    |     2
#   4 |    3 |        1     |        2     |       2    |     3
#   5 |    3 |        1     |        2     |       2    |     3
#   6 |    4 |        2     |        2     |       3    |     3
#   7 |    5 |        2     |        3     |       3    |     4
#   8 |    5 |        2     |        3     |       3    |     4
#   9 |    6 |        3     |        3     |       4    |     4
#  10 |    6 |        3     |        3     |       4    |     5
#  11 |    6 |        3     |        3     |       5    |     5
#  12 |    8 |        4     |        4     |       6    |     6

# %%
def display_ref_table(seq):
    print("  n | Q(n) | references")
    for ent in seq:
        cl = ent.least_ref() - (2 * ent.index)
        print("%3d | %4d |" % (ent.index, ent.num), ent.references)

# %%
def convert_to_graphable(seq):
    resx = []
    resy = []
    for ent in seq:
        resx.append(ent.index)
        resy.append(ent.num)
    return (np.array(resx),np.array(resy))

# %%
def scatter(sequence):
    graphable = convert_to_graphable(sequence)
    plt.scatter(graphable[0], graphable[1])
    plt.axline((0, 0), slope = 1)
    plt.show()

# %%
seq = default()
add_terms(1000)
scatter(seq)

# %%
seq = default()
seq.append(Entry(3, 1))
add_terms(1000)
scatter(seq[:100])

# %% [markdown]
# ## 6:2 does not work

# %%
seq = default()
seq.append(Entry(3, 2))
seq.append(Entry(4, 3))
seq.append(Entry(5, 5))
seq.append(Entry(6, 2))
add_terms(100)
scatter(seq)
# Out:
# accessing indeces  -1 ,  33
# DIED

# %% [markdown]
# ### But 6:3 does

# %%
seq = default()
seq.append(Entry(3, 2))
seq.append(Entry(4, 3))
seq.append(Entry(5, 5))
seq.append(Entry(6, 3))
add_terms(100)
scatter(seq)

# %%
def display_num_reference_list(seq):
    for ent in seq:
        print(str(ent.num_ref()) + ", ", end='')

# %%
display_num_reference_list(seq[:20])
# Out:
# 1, 2, 2, 5, 3, 1, 5, 5, 6, 6, 2, 1, 2, 3, 5, 8, 8, 6, 3, 2,

# %%
class meta:
    
    def __init__(self, entry):
        self.child = entry
        
    # conjecture: will always be 2 or more
    def three_n_minus_largest_ref(self):
        return 3 * self.child.index - self.child.greatest_ref()

# %%
def print_row(ent, *args):
    print("%3d |%4d " % (ent.index, ent.num), end='')
    for field in args:
        print("| %6d " % (field), end='')
    print()

# %%
def table1(seq):
    for ent in seq:
        m = meta(ent)
        print_row(ent, ent.greatest_ref(), m.three_n_minus_largest_ref())
        
table1(seq[:12])
# Out:
#   1 |   1 |      9 |     -6
#   2 |   1 |     10 |     -4
#   3 |   2 |     13 |     -4
#   4 |   3 |     14 |     -2
#   5 |   5 |     11 |      4
#   6 |   3 |     15 |      3
#   7 |   4 |     20 |      1
#   8 |   8 |     22 |      2
#   9 |   6 |     25 |      2
#  10 |   4 |     26 |      4
#  11 |   9 |     23 |     10
#  12 |  10 |     24 |     12

# %%
print(len(seq))

for ent in seq[400:]:
    m = meta(ent)
    if (m.three_n_minus_largest_ref() <= 1000):
        print_row(ent, ent.greatest_ref(), m.three_n_minus_largest_ref())
# Out:
# 106

# %%
seq[-1].num
# Out:
# 48

# %%
class StartData:
    def __init__(self, seq, reached):
        self.seq = seq.copy()
        self.reached = reached
        
    def __str__(self):
        return f"reached {self.reached} with {pretty_str(self.seq)}"

# %%
class Accumulator:
    def __init__(self):
        self.store = {};
        
    def add(self, level, start_seq, reached):
        if (level - 3 not in self.store):
            self.store[level - 3] = []
        self.store[level - 3].append(StartData(start_seq, reached))
        
    def display(self):
        for level in self.store:
            print(f"level {level}:")
            for node in self.store[level]:
                print(node)

# %%
def highest_defined(test, test_to=1000):
    global seq
    seq = test.copy()
    add_terms(test_to)
    if (len(seq) >= test_to):
        return 0
    return len(seq)

# %%
def recurse_discovery(start_seq, index, max_level):
    global acc
    if (index > max_level):
        return
    for val in range(1, index + 2):
        start_seq.append(Entry(index, val))
        reached = highest_defined(start_seq)
        if (reached > 0):
            acc.add(index, start_seq, reached)
        else:
            recurse_discovery(start_seq.copy(), index+1, max_level)
        start_seq.pop()

# %%
acc = Accumulator()
recurse_discovery(default(), 3, 7)
# Out:
# accessing indeces  -17 ,  30
# DIED
# accessing indeces  -45 ,  220
# DIED
# accessing indeces  0 ,  11
# DIED
# accessing indeces  -2 ,  11
# DIED
# accessing indeces  -4 ,  11
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -1 ,  22
# DIED
# accessing indeces  -6 ,  25
# DIED
# accessing indeces  -1 ,  91
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  0 ,  10
# DIED
# accessing indeces  -46 ,  219
# DIED
# accessing indeces  -1 ,  10
# DIED
# accessing indeces  -3 ,  10
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -2 ,  21
# DIED
# accessing indeces  -1 ,  91
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -10 ,  33
# DIED
# accessing indeces  0 ,  11
# DIED
# accessing indeces  -1 ,  20
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -7 ,  24
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -2 ,  7
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -1 ,  9
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  -2 ,  9
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -3 ,  20
# DIED
# accessing indeces  -7 ,  31
# DIED
# accessing indeces  -4 ,  11
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  0 ,  11
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -2 ,  27
# DIED
# accessing indeces  -57 ,  472
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -2 ,  7
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -11 ,  32
# DIED
# accessing indeces  0 ,  16
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -1 ,  42
# DIED
# accessing indeces  0 ,  18
# DIED
# accessing indeces  -18 ,  348
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  34
# DIED
# accessing indeces  0 ,  10
# DIED
# accessing indeces  -7 ,  244
# DIED
# accessing indeces  -2 ,  61
# DIED
# accessing indeces  -3 ,  10
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -1 ,  10
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  -8 ,  23
# DIED
# accessing indeces  -1 ,  6
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  8
# DIED
# accessing indeces  -1 ,  8
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  15
# DIED
# accessing indeces  0 ,  46
# DIED
# accessing indeces  0 ,  25
# DIED
# accessing indeces  -1 ,  18
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -73 ,  310
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -5 ,  77
# DIED
# accessing indeces  -12 ,  30
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -2 ,  27
# DIED
# accessing indeces  0 ,  10
# DIED
# accessing indeces  0 ,  21
# DIED
# accessing indeces  0 ,  20
# DIED
# accessing indeces  0 ,  8
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  -33 ,  46
# DIED
# accessing indeces  -12 ,  194
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -6 ,  35
# DIED
# accessing indeces  0 ,  16
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  0 ,  21
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -51 ,  349
# DIED
# accessing indeces  -5 ,  260
# DIED
# accessing indeces  -1 ,  18
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  0 ,  12
# DIED
# accessing indeces  -10 ,  86
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  0 ,  60
# DIED
# accessing indeces  -1 ,  19
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -15 ,  58
# DIED
# accessing indeces  -1 ,  18
# DIED
# accessing indeces  -8 ,  222
# DIED
# accessing indeces  -5 ,  109
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  16
# DIED
# accessing indeces  -1 ,  11
# DIED
# accessing indeces  -3 ,  11
# DIED
# accessing indeces  -1 ,  161
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -2 ,  7
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -1 ,  29
# DIED
# accessing indeces  0 ,  33
# DIED
# accessing indeces  -2 ,  11
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -10 ,  44
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -5 ,  29
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  0 ,  34
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  -3 ,  12
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -1 ,  10
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  15
# DIED
# accessing indeces  -6 ,  26
# DIED
# accessing indeces  0 ,  10
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -6 ,  145
# DIED
# accessing indeces  -7 ,  155
# DIED
# accessing indeces  0 ,  8
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -58 ,  471
# DIED
# accessing indeces  -11 ,  194
# DIED
# accessing indeces  0 ,  10
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  0 ,  12
# DIED
# accessing indeces  -3 ,  17
# DIED
# accessing indeces  0 ,  2
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -1 ,  6
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  23
# DIED
# accessing indeces  -1 ,  34
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  0 ,  12
# DIED
# accessing indeces  0 ,  22
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  0 ,  19
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -1 ,  15
# DIED
# accessing indeces  -6 ,  24
# DIED
# accessing indeces  -1 ,  13
# DIED
# accessing indeces  -1 ,  7
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -2 ,  7
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -2 ,  41
# DIED
# accessing indeces  -1 ,  17
# DIED
# accessing indeces  -10 ,  47
# DIED
# accessing indeces  -35 ,  247
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  -19 ,  347
# DIED
# accessing indeces  -1 ,  7
# DIED
# accessing indeces  -1 ,  25
# DIED
# accessing indeces  -4 ,  154
# DIED
# accessing indeces  -31 ,  156
# DIED
# accessing indeces  0 ,  2
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  -6 ,  41
# DIED
# accessing indeces  -9 ,  22
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -3 ,  8
# DIED
# accessing indeces  0 ,  6
# DIED
# accessing indeces  -5 ,  48
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -1 ,  10
# DIED
# accessing indeces  0 ,  4
# DIED
# accessing indeces  -3 ,  42
# DIED
# accessing indeces  -4 ,  24
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -13 ,  537
# DIED
# accessing indeces  -8 ,  101
# DIED
# accessing indeces  0 ,  2
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -4 ,  17
# DIED
# accessing indeces  0 ,  9
# DIED
# accessing indeces  0 ,  23
# DIED
# accessing indeces  0 ,  7
# DIED
# accessing indeces  -1 ,  33
# DIED
# accessing indeces  -1 ,  10
# DIED
# accessing indeces  -4 ,  9
# DIED
# accessing indeces  -1 ,  6
# DIED
# accessing indeces  -2 ,  35
# DIED
# accessing indeces  0 ,  36
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  -1 ,  9
# DIED
# accessing indeces  -8 ,  243
# DIED
# accessing indeces  0 ,  21
# DIED
# accessing indeces  0 ,  2
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  0 ,  5
# DIED
# accessing indeces  0 ,  3
# DIED
# accessing indeces  -1 ,  7
# DIED
# accessing indeces  0 ,  3
# DIED

# %%
acc.display()
# Out:
# level 4:
# reached 32 with 1-> 1-> 1-> 1-> 1-> 1-> 3->
# reached 311 with 1-> 1-> 1-> 1-> 1-> 1-> 4->
# reached 13 with 1-> 1-> 1-> 1-> 1-> 1-> 5->
# reached 13 with 1-> 1-> 1-> 1-> 1-> 1-> 6->
# reached 13 with 1-> 1-> 1-> 1-> 1-> 1-> 7->
# reached 7 with 1-> 1-> 2-> 3-> 3-> 6-> 8->
# reached 13 with 1-> 1-> 2-> 3-> 4-> 1-> 4->
# reached 11 with 1-> 1-> 2-> 3-> 4-> 1-> 5->
# reached 63 with 1-> 1-> 2-> 3-> 4-> 1-> 6->
# reached 30 with 1-> 1-> 2-> 3-> 4-> 1-> 7->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 1-> 8->
# reached 10 with 1-> 1-> 2-> 3-> 4-> 2-> 7->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 2-> 8->
# reached 63 with 1-> 1-> 2-> 3-> 4-> 3-> 1->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 3-> 8->
# reached 14 with 1-> 1-> 2-> 3-> 4-> 4-> 1->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 4-> 8->
# reached 68 with 1-> 1-> 2-> 3-> 4-> 5-> 1->
# reached 31 with 1-> 1-> 2-> 3-> 4-> 5-> 2->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 5-> 8->
# reached 910 with 1-> 1-> 2-> 3-> 4-> 6-> 2->
# reached 160 with 1-> 1-> 2-> 3-> 4-> 6-> 5->
# reached 7 with 1-> 1-> 2-> 3-> 4-> 6-> 8->
# reached 38 with 1-> 1-> 2-> 3-> 5-> 1-> 3->
# reached 11 with 1-> 1-> 2-> 3-> 5-> 1-> 5->
# reached 50 with 1-> 1-> 2-> 3-> 5-> 1-> 7->
# reached 7 with 1-> 1-> 2-> 3-> 5-> 1-> 8->
# reached 12 with 1-> 1-> 2-> 3-> 5-> 3-> 1->
# reached 11 with 1-> 1-> 2-> 3-> 5-> 3-> 2->
# reached 8 with 1-> 1-> 2-> 3-> 5-> 3-> 3->
# reached 47 with 1-> 1-> 2-> 3-> 5-> 3-> 6->
# reached 68 with 1-> 1-> 2-> 3-> 5-> 3-> 7->
# reached 7 with 1-> 1-> 2-> 3-> 5-> 3-> 8->
# level 3:
# reached 22 with 1-> 1-> 1-> 1-> 1-> 3->
# reached 310 with 1-> 1-> 1-> 1-> 1-> 4->
# reached 12 with 1-> 1-> 1-> 1-> 1-> 5->
# reached 12 with 1-> 1-> 1-> 1-> 1-> 6->
# reached 6 with 1-> 1-> 1-> 1-> 1-> 7->
# reached 36 with 1-> 1-> 1-> 1-> 2-> 1->
# reached 36 with 1-> 1-> 1-> 1-> 2-> 4->
# reached 9 with 1-> 1-> 1-> 1-> 2-> 5->
# reached 9 with 1-> 1-> 1-> 1-> 2-> 6->
# reached 6 with 1-> 1-> 1-> 1-> 2-> 7->
# reached 9 with 1-> 1-> 1-> 2-> 2-> 5->
# reached 9 with 1-> 1-> 1-> 2-> 2-> 6->
# reached 6 with 1-> 1-> 1-> 2-> 2-> 7->
# reached 44 with 1-> 1-> 1-> 2-> 3-> 1->
# reached 16 with 1-> 1-> 1-> 2-> 3-> 6->
# reached 6 with 1-> 1-> 1-> 2-> 3-> 7->
# reached 25 with 1-> 1-> 2-> 2-> 1-> 6->
# reached 6 with 1-> 1-> 2-> 2-> 1-> 7->
# reached 9 with 1-> 1-> 2-> 2-> 2-> 6->
# reached 6 with 1-> 1-> 2-> 2-> 2-> 7->
# reached 16 with 1-> 1-> 2-> 2-> 3-> 6->
# reached 6 with 1-> 1-> 2-> 2-> 3-> 7->
# reached 23 with 1-> 1-> 2-> 2-> 4-> 1->
# reached 694 with 1-> 1-> 2-> 2-> 4-> 4->
# reached 6 with 1-> 1-> 2-> 2-> 4-> 7->
# reached 28 with 1-> 1-> 2-> 3-> 2-> 4->
# reached 9 with 1-> 1-> 2-> 3-> 2-> 6->
# reached 6 with 1-> 1-> 2-> 3-> 2-> 7->
# reached 57 with 1-> 1-> 2-> 3-> 3-> 1->
# reached 30 with 1-> 1-> 2-> 3-> 3-> 2->
# reached 532 with 1-> 1-> 2-> 3-> 3-> 5->
# reached 6 with 1-> 1-> 2-> 3-> 3-> 7->
# reached 6 with 1-> 1-> 2-> 3-> 4-> 7->
# reached 52 with 1-> 1-> 2-> 3-> 5-> 2->
# reached 14 with 1-> 1-> 2-> 3-> 5-> 4->
# reached 396 with 1-> 1-> 2-> 3-> 5-> 5->
# reached 26 with 1-> 1-> 2-> 3-> 5-> 6->
# reached 6 with 1-> 1-> 2-> 3-> 5-> 7->
# level 2:
# reached 21 with 1-> 1-> 1-> 1-> 3->
# reached 11 with 1-> 1-> 1-> 1-> 4->
# reached 11 with 1-> 1-> 1-> 1-> 5->
# reached 5 with 1-> 1-> 1-> 1-> 6->
# reached 35 with 1-> 1-> 1-> 2-> 1->
# reached 35 with 1-> 1-> 1-> 2-> 4->
# reached 8 with 1-> 1-> 1-> 2-> 5->
# reached 5 with 1-> 1-> 1-> 2-> 6->
# reached 8 with 1-> 1-> 2-> 2-> 5->
# reached 5 with 1-> 1-> 2-> 2-> 6->
# reached 30 with 1-> 1-> 2-> 3-> 1->
# reached 5 with 1-> 1-> 2-> 3-> 6->
# level 1:
# reached 13 with 1-> 1-> 1-> 3->
# reached 10 with 1-> 1-> 1-> 4->
# reached 4 with 1-> 1-> 1-> 5->
# reached 18 with 1-> 1-> 2-> 1->
# reached 7 with 1-> 1-> 2-> 4->
# reached 4 with 1-> 1-> 2-> 5->
# level 0:
# reached 12 with 1-> 1-> 3->
# reached 3 with 1-> 1-> 4->

# %%
def gen_seq(arr):
    seq = []
    for (i, n) in enumerate(arr):
        seq.append(Entry(i+1, n))
    return seq

# %%
1-> 1-> 1-> 2-> 2-> 2-> 1-> 1-> 4->

# %%
seq = gen_seq([1, 1, 1, 1, 2, 5])
pretty_print()
add_terms(1000)
display_wide_table(seq)
# Out:
# accessing indeces  0 ,  7
# DIED
#   n | Q(n) | Q(n - (n-1)) | Q(n - (n-2)) | n - Q(n-1) | n - Q(n-2)
#   1 |    1 |              |              |            |
#   2 |    1 |              |              |            |
#   3 |    1 |        1     |        1     |       2    |     2
#   4 |    1 |        1     |        1     |       3    |     3
#   5 |    2 |        1     |        1     |       4    |     4
#   6 |    5 |        1     |        2     |       4    |     5
#   7 |    3 |        1     |        2     |       2    |     5
#   8 |    3 |        2     |        1     |       5    |     3
#   9 |   10 |        5     |        5     |       6    |     6

# %%
scatter(seq)
